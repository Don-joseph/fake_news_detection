# %%
import urllib.request,sys,time
from bs4 import BeautifulSoup
import requests
import pandas as pd


pagesToGet= 500
upperframe=[]  
for page in range(1,pagesToGet+1):
    print('processing page :', page)
    url = 'https://www.politifact.com/factchecks/list/?page='+str(page)
    print(url)
    
    try:

        page=requests.get(url)                            
    
    except Exception as e:                                   
        error_type, error_obj, error_info = sys.exc_info()      
        print ('ERROR FOR LINK:',url)                         
        print (error_type, 'Line:', error_info.tb_lineno)     
        continue                                              
    time.sleep(2)   
    soup=BeautifulSoup(page.text,'html.parser')
    frame=[]
    links=soup.find_all('li',attrs={'class':'o-listicle__item'})
    print(len(links))
    filename="NEWS.csv"
    f=open(filename,"w", encoding = 'utf-8')
    headers="Statement,Link,Date, Source, Label\n"
    f.write(headers)
    
    for j in links:
        Statement = j.find("div",attrs={'class':'m-statement__quote'}).text.strip()
        Link = "https://www.politifact.com"
        Link += j.find("div",attrs={'class':'m-statement__quote'}).find('a')['href'].strip()
        Date = j.find('div',attrs={'class':'m-statement__body'}).find('footer').text[-14:-1].strip()
        Source = j.find('div', attrs={'class':'m-statement__meta'}).find('a').text.strip()
        Label = j.find('div', attrs ={'class':'m-statement__content'}).find('img',attrs={'class':'c-image__original'}).get('alt').strip()
        frame.append((Statement,Link,Date,Source,Label))
        f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")
    upperframe.extend(frame)
f.close()
data=pd.DataFrame(upperframe, columns=['Statement','Link','Date','Source','Label'])
data
# Out:
# processing page : 1
# https://www.politifact.com/factchecks/list/?page=1
# 30
# processing page : 2
# https://www.politifact.com/factchecks/list/?page=2
# 30
# processing page : 3
# https://www.politifact.com/factchecks/list/?page=3
# 30
# [('A video shows lawmakers in compromising positions with children.', 'https://www.politifact.com/factchecks/2022/dec/16/viral-image/no-these-images-dont-show-politicians-acting-inapp/', 'mber 16, 2022', 'Viral image', 'pants-fire'), ('A “well-crafted garlic salve” can “heal any ailment of the lungs and respiratory system.”', 'https://www.politifact.com/factchecks/2022/dec/16/instagram-posts/no-garlic-salve-cannot-be-used-treat-rsv-croup-or/', 'mber 16, 2022', 'Instagram posts', 'false'), ('A video shows Rep. Jim Jordan threatening House Speaker Nancy Pelosi with “‘possible’ jail time.”', 'https://www.politifact.com/factchecks/2022/dec/16/facebook-posts/no-this-video-doesnt-show-jim-jordan-threatening-n/', 'mber 16, 2022', 'Facebook posts', 'pants-fire'), ('Says U.S. Rep. Katie Porter, D-Calif., “says pedophilia isn’t a crime — it’s an identity.”', 'https://www.politifact.com/factchecks/2022/dec/16/viral-image/katie-porter-didnt-call-pedophilia-an-identity/', 'mber 16, 2022', 'Viral image', 'pants-fire'), ('"Latina workers make 54 cents for every dollar earned by white, non-Hispanic men."', 'https://www.politifact.com/factchecks/2022/dec/16/tammy-baldwin/yes-wage-gap-does-have-big-impact-latina-workers/', 'mber 16, 2022', 'Tammy Baldwin', 'true'), ('Human traffickers are putting toxin-laced tissues on gas pumps and door handles, then waiting for potential victims to pass out.', 'https://www.politifact.com/factchecks/2022/dec/16/instagram-posts/no-evidence-human-traffickers-using-toxic-tissues/', 'mber 16, 2022', 'Instagram posts', 'false'), ('The COVID-19 vaccines were linked to the deaths of 80 Canadian doctors.', 'https://www.politifact.com/factchecks/2022/dec/16/instagram-posts/claims-80-canadian-doctors-died-because-covid-19-v/', 'mber 16, 2022', 'Instagram posts', 'false'), ('There are a record high cases of flu in the U.S. this year, and “last year there were none.”', 'https://www.politifact.com/factchecks/2022/dec/15/instagram-posts/influenza-caused-9-million-illnesses-5000-deaths-l/', 'mber 15, 2022', 'Instagram posts', 'false'), ('Stephen Boss died because of the COVID-19 vaccine.', 'https://www.politifact.com/factchecks/2022/dec/15/tweets/tephen-twitch-boss-didnt-die-because-of-the-covid/', 'mber 15, 2022', 'Tweets', 'false'), ('Video shows Sen. John Kennedy telling Secretary of Homeland Security Alejandro Mayorkas, “You will be impeached.”', 'https://www.politifact.com/factchecks/2022/dec/15/facebook-posts/video-doesnt-show-senator-telling-mayorkas-he-woul/', 'mber 15, 2022', 'Facebook posts', 'false'), ('Video shows Attorney General Merrick Garland saying, “Wait for revenge.”', 'https://www.politifact.com/factchecks/2022/dec/15/facebook-posts/no-merrick-garland-doesnt-tell-john-kennedy-to-wai/', 'mber 15, 2022', 'Facebook posts', 'pants-fire'), ('Kari Lake’s lawsuit “exposes Arizona used no signature verification.”', 'https://www.politifact.com/factchecks/2022/dec/15/facebook-posts/kari-lakes-lawsuit-does-not-show-arizona-failed-to/', 'mber 15, 2022', 'Facebook posts', 'false'), ('England’s Oxfordshire County Council has passed a trial "climate lockdown," “confining residents to their own neighbourhoods.”', 'https://www.politifact.com/factchecks/2022/dec/15/facebook-posts/no-a-traffic-management-plan-is-not-a-climate-lock/', 'mber 15, 2022', 'Facebook posts', 'false'), ('Pfizer confirmed stiff-person syndrome is an adverse effect of the COVID-19 vaccine.', 'https://www.politifact.com/factchecks/2022/dec/15/instagram-posts/pfizer-didnt-say-covid-vaccine-causes-stiff-person/', 'mber 15, 2022', 'Instagram posts', 'false'), ('Grant Wahl died because of the COVID-19 vaccine.', 'https://www.politifact.com/factchecks/2022/dec/14/facebook-posts/grant-wahl-died-ruptured-aortic-aneurysm-not-covid/', 'mber 14, 2022', 'Facebook posts', 'false'), ('Sen. Kyrsten Sinema "voted with the president 93% of the time."', 'https://www.politifact.com/factchecks/2022/dec/14/karine-jean-pierre/sinema-voted-biden-most-time-less-often-majori ...
#                                             Statement  \
# 0   A video shows lawmakers in compromising positi...
# 1   A “well-crafted garlic salve” can “heal any ai...
# 2   A video shows Rep. Jim Jordan threatening Hous...
# 3   Says U.S. Rep. Katie Porter, D-Calif., “says p...
# 4   "Latina workers make 54 cents for every dollar...
# ..                                                ...
# 85  The Biden administration is deporting Cubans “...
# 86  Suggests "108 FIFA registered players/coaches ...
# 87  The College of Physicians and Surgeons of Onta...
# 88  “Joe Biden is being investigated for human tra...
# 89  Herschel Walker “wants a nationwide ban on abo...
#
#                                                  Link           Date  \
# 0   https://www.politifact.com/factchecks/2022/dec...  mber 16, 2022
# 1   https://www.politifact.com/factchecks/2022/dec...  mber 16, 2022
# 2   https://www.politifact.com/factchecks/2022/dec...  mber 16, 2022
# 3   https://www.politifact.com/factchecks/2022/dec...  mber 16, 2022
# 4   https://www.politifact.com/factchecks/2022/dec...  mber 16, 2022
# ..                                                ...            ...
# 85  https://www.politifact.com/factchecks/2022/nov...  mber 23, 2022
# 86  https://www.politifact.com/factchecks/2022/nov...  mber 22, 2022
# 87  https://www.politifact.com/factchecks/2022/nov...  mber 22, 2022
# 88  https://www.politifact.com/factchecks/2022/nov...  mber 22, 2022
# 89  https://www.politifact.com/factchecks/2022/nov...  mber 22, 2022
#
#              Source        Label
# 0       Viral image   pants-fire
# 1   Instagram posts        false
# 2    Facebook posts   pants-fire
# 3       Viral image   pants-fire
# 4     Tammy Baldwin         true
# ..              ...          ...
# 85  Instagram posts        false
# 86  Instagram posts        false
# 87     TikTok posts        false
# 88  Instagram posts        false
# 89  Raphael Warnock  mostly-true
#
# [90 rows x 5 columns]

# %%
filename="NEWS.csv"
f=open(filename,"w")
headers="Statement,Link,Date, Source, Label\n"
f.write(headers)
f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")
# Out:
# 289

# %%
f.write(Statement.replace(",","^")+","+Link+","+Date.replace(",","^")+","+Source.replace(",","^")+","+Label.replace(",","^")+"\n")

# %%
path = 'C:\\Users\\donjo\\OneDrive\\Desktop\\dmml\\'
data.to_csv(path+'NEWS.csv')

# %%
import os
data.to_csv(os.path.join(path,'//NEWS.csv'))
